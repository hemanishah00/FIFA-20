# %% [markdown]
# ### Link to your presentation video here

# %% [markdown]
# Team Members: Navya sri Kalli, Kuldeep Prasad, Hemani Shah, Rohit Raj

# %% [markdown]
# **Steps implemented**
#
#
# *   Importing necessary libraries
# *   Visualizing the data
#
# *   Data preprocessing
# *   Hypothesis testing
#
# *   Removing columns that are highly correlated
# *   Implementing linear regression
#
# *   Preprocessing players_20 dataset
# *   preparing the test data
#
# *   Predicting and computing the results
# *   The best player

# %% [markdown]
# ## **Importing necessary libraries**

# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# ## **Visualising the data**

# %%
#Reading the data
df=pd.read_csv("https://raw.githubusercontent.com/rraj29/data/main/players_19.csv")
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1     158023  https://sofifa.com/player/158023/lionel-messi/...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     193080  https://sofifa.com/player/193080/david-de-gea-...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name  age         dob  \
# 0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   33  1985-02-05
# 1           L. Messi       Lionel Andrés Messi Cuccittini   31  1987-06-24
# 2          Neymar Jr        Neymar da Silva Santos Junior   26  1992-02-05
# 3             De Gea                David De Gea Quintana   27  1990-11-07
# 4       K. De Bruyne                      Kevin De Bruyne   27  1991-06-28
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# 0        187         83    Portugal             Juventus  ...  65+3  61+3
# 1        170         72   Argentina         FC Barcelona  ...  63+2  61+2
# 2        175         68      Brazil  Paris Saint-Germain  ...  65+3  60+3
# 3        193         76       Spain    Manchester United  ...   NaN   NaN
# 4        181         70     Belgium      Manchester City  ...  77+3  77+3
#
#     cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0  61+3  61+3  65+3  61+3  53+3  53+3  53+3  61+3
# 1  61+2  61+2  63+2  58+2  47+2  47+2  47+2  58+2
# 2  60+3  60+3  65+3  60+3  47+3  47+3  47+3  60+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  77+3  77+3  77+3  73+3  66+3  66+3  66+3  73+3
#
# [5 rows x 104 columns]

# %%
df.shape
# Out:
# (17770, 104)

# %%
df.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg       overall  \
# count   17770.000000  17770.000000  17770.000000  17770.000000  17770.000000
# mean   213797.776308     25.193922    181.253292     75.310917     66.240405
# std     29955.746535      4.651957      6.745892      7.080013      6.994104
# min       164.000000     16.000000    154.000000     50.000000     47.000000
# 25%    199803.000000     21.000000    176.000000     70.000000     62.000000
# 50%    221350.500000     25.000000    181.000000     75.000000     66.000000
# 75%    235967.750000     28.000000    186.000000     80.000000     71.000000
# max    246063.000000     45.000000    205.000000    110.000000     94.000000
#
#           potential     value_eur       wage_eur  international_reputation  \
# count  17770.000000  1.777000e+04   17770.000000              17770.000000
# mean      71.382949  2.440756e+06    9956.162071                  1.117783
# std        6.145171  5.644779e+06   22330.640048                  0.401085
# min       48.000000  0.000000e+00       0.000000                  1.000000
# 25%       67.000000  3.000000e+05    1000.000000                  1.000000
# 50%       71.000000  6.750000e+05    3000.000000                  1.000000
# 75%       75.000000  2.000000e+06    9000.000000                  1.000000
# max       95.000000  1.185000e+08  565000.000000                  5.000000
#
#           weak_foot  ...       passing     dribbling     defending  \
# count  17770.000000  ...  15784.000000  15784.000000  15784.000000
# mean       2.946427  ...     57.082172     62.267169     51.665484
# std        0.659353  ...     10.589207     10.442659     16.347564
# min        1.000000  ...     24.000000     23.000000     15.000000
# 25%        3.000000  ...     50.000000     57.000000     37.000000
# 50%        3.000000  ...     58.000000     64.000000     56.000000
# 75%        3.000000  ...     64.000000     69.000000     65.000000
# max        5.000000  ...     92.000000     96.000000     91.000000
#
#              physic    gk_diving  gk_handling   gk_kicking  gk_reflexes  \
# count  15784.000000  1986.000000  1986.000000  1986.000000  1986.000000
# mean      64.972567    65.374622    62.931017    61.511078    66.149043
# std        9.745859     7.807033     7.556389     7.667533     8.234898
# min       30.000000    45.000000    43.000000    35.000000    44.000000
# 25%       59.000000    60.000000    58.000000    56.000000    60.000000
# 50%       66.000000    65.000000    63.000000    61.000000    66.000000
# 75%       72.000000    71.000000    68.000000    66.000000    72.000000
# max       89.000000    91.000000    92.000000    91.000000    94.000000
#
#           gk_speed  gk_positioning
# count  1986.000000     1986.000000
# mean     38.675730       63.088117
# std      10.420846        8.664458
# min      12.000000       38.000000
# 25%      30.000000       57.000000
# 50%      40.000000       63.000000
# 75%      46.000000       69.000000
# max      65.000000       90.000000
#
# [8 rows x 27 columns]

# %%
df.info(verbose=True,show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17770 entries, 0 to 17769
# Data columns (total 104 columns):
#  #    Column                      Non-Null Count  Dtype
# ---   ------                      --------------  -----
#  0    sofifa_id                   17770 non-null  int64
#  1    player_url                  17770 non-null  object
#  2    short_name                  17770 non-null  object
#  3    long_name                   17770 non-null  object
#  4    age                         17770 non-null  int64
#  5    dob                         17770 non-null  object
#  6    height_cm                   17770 non-null  int64
#  7    weight_kg                   17770 non-null  int64
#  8    nationality                 17770 non-null  object
#  9    club                        17770 non-null  object
#  10   overall                     17770 non-null  int64
#  11   potential                   17770 non-null  int64
#  12   value_eur                   17770 non-null  int64
#  13   wage_eur                    17770 non-null  int64
#  14   player_positions            17770 non-null  object
#  15   preferred_foot              17770 non-null  object
#  16   international_reputation    17770 non-null  int64
#  17   weak_foot                   17770 non-null  int64
#  18   skill_moves                 17770 non-null  int64
#  19   work_rate                   17770 non-null  object
#  20   body_type                   17770 non-null  object
#  21   real_face                   17770 non-null  object
#  22   release_clause_eur          16257 non-null  float64
#  23   player_tags                 1516 non-null   object
#  24   team_position               17547 non-null  object
#  25   team_jersey_number          17547 non-null  float64
#  26   loaned_from                 1281 non-null   object
#  27   joined                      16266 non-null  object
#  28   contract_valid_until        17547 non-null  float64
#  29   nation_position             1104 non-null   object
#  30   nation_jersey_number        1104 non-null   float64
#  31   pace                        15784 non-null  float64
#  32   shooting                    15784 non-null  float64
#  33   passing                     15784 non-null  float64
#  34   dribbling                   15784 non-null  float64
#  35   defending                   15784 non-null  float64
#  36   physic                      15784 non-null  float64
#  37   gk_diving                   1986 non-null   float64
#  38   gk_handling                 1986 non-null   float64
#  39   gk_kicking                  1986 non-null   float64
#  40   gk_reflexes                 1986 non-null   float64
#  41   gk_speed                    1986 non-null   float64
#  42   gk_positioning              1986 non-null   float64
#  43   player_traits               8010 non-null   object
#  44   attacking_crossing          17770 non-null  object
#  45   attacking_finishing         17770 non-null  object
#  46   attacking_heading_accuracy  17770 non-null  object
#  47   attacking_short_passing     17770 non-null  object
#  48   attacking_volleys           17770 non-null  object
#  49   skill_dribbling             17770 non-null  object
#  50   skill_curve                 17770 non-null  object
#  51   skill_fk_accuracy           17770 non-null  object
#  52   skill_long_passing          17770 non-null  object
#  53   skill_ball_control          17770 non-null  object
#  54   movement_acceleration       17770 non-null  object
#  55   movement_sprint_speed       17770 non-null  object
#  56   movement_agility            17770 non-null  object
#  57   movement_reactions          17770 non-null  object
#  58   movement_balance            17770 non-null  object
#  59   power_shot_power            17770 non-null  object
#  60   power_jumping               17770 non-null  object
#  61   power_stamina               17770 non-null  object
#  62   power_strength              17770 non-null  object
#  63   power_long_shots            17770 non-null  object
#  64   mentality_aggression        17770 non-null  object
#  65   mentality_interceptions     17770 non-null  object
#  66   mentality_positioning       17770 non-null  object
#  67   mentality_vision            17770 non-null  object
#  68   mentality_penalties         17770 non-null  object
#  69   mentality_composure         17770 non-null  object
#  70   defending_marking           17770 non-null  object
#  71   defending_standing_tackle   17770 non-null  object
#  72   defending_sliding_tackle    17770 non-null  object
#  73   goalkeeping_diving          17770 non-null  object
#  74   goalkeeping_handling        17770 non-null  object
#  75   goalkeeping_kicking         17770 non-null  object
#  76   goalkeeping_positioning     17770 non-null  object
#  77   goalkeeping_reflexes        17770 non-null  object
#  78   ls                          15784 non-null  object
#  79   st                          15784 non-null  object
#  80   rs                          15784 non-null  object
#  81   lw                          15784 non-null  object
#  82   lf                          15784 non-null  object
#  83   cf                          15784 non-null  object
#  84   rf                          15784 non-null  object
#  85   rw                          15784 non-null  object
#  86   lam                         15784 non-null  object
#  87   cam                         15784 non-null  object
#  88   ram                         15784 non-null  object
#  89   lm                          15784 non-null  object
#  90   lcm                         15784 non-null  object
#  91   cm                          15784 non-null  object
#  92   rcm                         15784 non-null  object
#  93   rm                          15784 non-null  object
#  94   lwb                         15784 non-null  object
#  95   ldm                         15784 non-null  object
#  96   cdm                         15784 non-null  object
#  97   rdm                         15784 non-null  object
#  98   rwb                         15784 non-null  object
#  99   lb                          15784 non-null  object
#  100  lcb                         15784 non-null  object
#  101  cb                          15784 non-null  object
#  102  rcb                         15784 non-null  object
#  103  rb                          15784 non-null  object
# dtypes: float64(16), int64(11), object(77)
# memory usage: 14.1+ MB

# %% [markdown]
# **Observations in this section**
#
# Initially, dataset has 17770 rows and 104 columns of which 16 columns are float type, 11 are int type, and 77 are object type. Redundant columns and columns with null values are observed.

# %% [markdown]
# ## **Data Preprocessing**

# %% [markdown]
# Removing the obvious column and rows which should not make a big difference to the model

# %%
#Remove the last 31 columns 
df = df.iloc[: , :-31]

# Remove the columns suggested in the project description
df.drop(["sofifa_id", "player_url", "short_name","long_name", "real_face", "potential"],axis=1,inplace=True)

# Remove the columns that should not make a difference
df.drop(["dob", "nationality", "club", "player_positions", "body_type", "loaned_from", "joined", "contract_valid_until"],axis=1,inplace=True)

# Removing the columns for team_jersey_number and nation_jersey_number. These should not make a difference
df.drop(["player_tags", "team_jersey_number", "nation_jersey_number"],axis=1,inplace=True)

# %%
df.info(verbose=True,show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17770 entries, 0 to 17769
# Data columns (total 56 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         17770 non-null  int64
#  1   height_cm                   17770 non-null  int64
#  2   weight_kg                   17770 non-null  int64
#  3   overall                     17770 non-null  int64
#  4   value_eur                   17770 non-null  int64
#  5   wage_eur                    17770 non-null  int64
#  6   preferred_foot              17770 non-null  object
#  7   international_reputation    17770 non-null  int64
#  8   weak_foot                   17770 non-null  int64
#  9   skill_moves                 17770 non-null  int64
#  10  work_rate                   17770 non-null  object
#  11  release_clause_eur          16257 non-null  float64
#  12  team_position               17547 non-null  object
#  13  nation_position             1104 non-null   object
#  14  pace                        15784 non-null  float64
#  15  shooting                    15784 non-null  float64
#  16  passing                     15784 non-null  float64
#  17  dribbling                   15784 non-null  float64
#  18  defending                   15784 non-null  float64
#  19  physic                      15784 non-null  float64
#  20  gk_diving                   1986 non-null   float64
#  21  gk_handling                 1986 non-null   float64
#  22  gk_kicking                  1986 non-null   float64
#  23  gk_reflexes                 1986 non-null   float64
#  24  gk_speed                    1986 non-null   float64
#  25  gk_positioning              1986 non-null   float64
#  26  player_traits               8010 non-null   object
#  27  attacking_crossing          17770 non-null  object
#  28  attacking_finishing         17770 non-null  object
#  29  attacking_heading_accuracy  17770 non-null  object
#  30  attacking_short_passing     17770 non-null  object
#  31  attacking_volleys           17770 non-null  object
#  32  skill_dribbling             17770 non-null  object
#  33  skill_curve                 17770 non-null  object
#  34  skill_fk_accuracy           17770 non-null  object
#  35  skill_long_passing          17770 non-null  object
#  36  skill_ball_control          17770 non-null  object
#  37  movement_acceleration       17770 non-null  object
#  38  movement_sprint_speed       17770 non-null  object
#  39  movement_agility            17770 non-null  object
#  40  movement_reactions          17770 non-null  object
#  41  movement_balance            17770 non-null  object
#  42  power_shot_power            17770 non-null  object
#  43  power_jumping               17770 non-null  object
#  44  power_stamina               17770 non-null  object
#  45  power_strength              17770 non-null  object
#  46  power_long_shots            17770 non-null  object
#  47  mentality_aggression        17770 non-null  object
#  48  mentality_interceptions     17770 non-null  object
#  49  mentality_positioning       17770 non-null  object
#  50  mentality_vision            17770 non-null  object
#  51  mentality_penalties         17770 non-null  object
#  52  mentality_composure         17770 non-null  object
#  53  defending_marking           17770 non-null  object
#  54  defending_standing_tackle   17770 non-null  object
#  55  defending_sliding_tackle    17770 non-null  object
# dtypes: float64(13), int64(9), object(34)
# memory usage: 7.6+ MB

# %%
#dropping rows of players who do not have a team position
na = pd.notnull(df["team_position"])
df = df[na]

# %%
df.shape
# Out:
# (17547, 56)

# %% [markdown]
# Replacing missing values in certain columns with "0" to indicate that player has not used that skill anytime

# %%
#filling missing values with "0"
for i in df.columns[14:26]:
    print("filling missing values in :"+i)
    df[i]=df[i].fillna(0)
df["release_clause_eur"].fillna(0.0, inplace=True)
# Out:
# filling missing values in :pace
# filling missing values in :shooting
# filling missing values in :passing
# filling missing values in :dribbling
# filling missing values in :defending
# filling missing values in :physic
# filling missing values in :gk_diving
# filling missing values in :gk_handling
# filling missing values in :gk_kicking
# filling missing values in :gk_reflexes
# filling missing values in :gk_speed
# filling missing values in :gk_positioning

# %% [markdown]
# Certain columns have values in the form of "a+b" or "a-b". Replacing those values with results obtained after evaluating the expressions

# %%
#replacing values with accurate data in columns which contain expressions
for i in df.columns[27:]:
    print("evaluating values in column :"+i)
    df[i]=df[i].apply(lambda x: eval(x) if isinstance(x,str) else x)
# Out:
# evaluating values in column :attacking_crossing
# evaluating values in column :attacking_finishing
# evaluating values in column :attacking_heading_accuracy
# evaluating values in column :attacking_short_passing
# evaluating values in column :attacking_volleys
# evaluating values in column :skill_dribbling
# evaluating values in column :skill_curve
# evaluating values in column :skill_fk_accuracy
# evaluating values in column :skill_long_passing
# evaluating values in column :skill_ball_control
# evaluating values in column :movement_acceleration
# evaluating values in column :movement_sprint_speed
# evaluating values in column :movement_agility
# evaluating values in column :movement_reactions
# evaluating values in column :movement_balance
# evaluating values in column :power_shot_power
# evaluating values in column :power_jumping
# evaluating values in column :power_stamina
# evaluating values in column :power_strength
# evaluating values in column :power_long_shots
# evaluating values in column :mentality_aggression
# evaluating values in column :mentality_interceptions
# evaluating values in column :mentality_positioning
# evaluating values in column :mentality_vision
# evaluating values in column :mentality_penalties
# evaluating values in column :mentality_composure
# evaluating values in column :defending_marking
# evaluating values in column :defending_standing_tackle
# evaluating values in column :defending_sliding_tackle

# %%
#label encoding preferred foot column
df["preferred_foot"] = df["preferred_foot"].map({"Left":0, 'Right':1})
#replacing nation position with 0/1 to indicate whether a player has palyed for the nation or not. 
#Rank of the player depends on this type of metric too.
df["nation_position"]= df["nation_position"].apply(lambda x:0 if x == np.nan else 1)

# %%
#Encoding team position column
df["team_position"].replace('RES', 'GK', inplace=True)
df["team_position"].replace('SUB', 'GK', inplace=True)
df_encoded_team=pd.get_dummies(df["team_position"],prefix="team",drop_first=False)
df=pd.concat([df,df_encoded_team],axis=1)
df.drop(["team_position"],axis=1,inplace=True)

# %%
#Encoding work rate column
df["work_rate_att"]=df["work_rate"].apply(lambda x: x.split("/")[0])
df["work_rate_def"]=df["work_rate"].apply(lambda x: x.split("/")[1])
df_att=pd.get_dummies(df["work_rate_att"],prefix="work_rate_att",drop_first=False)
df_def=pd.get_dummies(df["work_rate_def"],prefix="work_rate_def",drop_first=False)
df=pd.concat([df,df_att,df_def],axis=1)
df.drop(["work_rate", "work_rate_att", "work_rate_def"],axis=1,inplace=True)

# %%
#Replacing players traits column with the count of number of traits a player has
#This helps the model to learn something out of this predictor instead of removing it completely.
df["player_traits"].fillna('', inplace=True)
for i in range(df.shape[0]):
    a=df["player_traits"].iloc[i]
    b=len(a.split(','))
    if a=='':
        b=0
    df["player_traits"].iloc[i]=b

# %%
df.shape
# Out:
# (17547, 87)

# %%
df.info(verbose=True,show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17547 entries, 0 to 17769
# Data columns (total 87 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         17547 non-null  int64
#  1   height_cm                   17547 non-null  int64
#  2   weight_kg                   17547 non-null  int64
#  3   overall                     17547 non-null  int64
#  4   value_eur                   17547 non-null  int64
#  5   wage_eur                    17547 non-null  int64
#  6   preferred_foot              17547 non-null  int64
#  7   international_reputation    17547 non-null  int64
#  8   weak_foot                   17547 non-null  int64
#  9   skill_moves                 17547 non-null  int64
#  10  release_clause_eur          17547 non-null  float64
#  11  nation_position             17547 non-null  int64
#  12  pace                        17547 non-null  float64
#  13  shooting                    17547 non-null  float64
#  14  passing                     17547 non-null  float64
#  15  dribbling                   17547 non-null  float64
#  16  defending                   17547 non-null  float64
#  17  physic                      17547 non-null  float64
#  18  gk_diving                   17547 non-null  float64
#  19  gk_handling                 17547 non-null  float64
#  20  gk_kicking                  17547 non-null  float64
#  21  gk_reflexes                 17547 non-null  float64
#  22  gk_speed                    17547 non-null  float64
#  23  gk_positioning              17547 non-null  float64
#  24  player_traits               17547 non-null  object
#  25  attacking_crossing          17547 non-null  int64
#  26  attacking_finishing         17547 non-null  int64
#  27  attacking_heading_accuracy  17547 non-null  int64
#  28  attacking_short_passing     17547 non-null  int64
#  29  attacking_volleys           17547 non-null  int64
#  30  skill_dribbling             17547 non-null  int64
#  31  skill_curve                 17547 non-null  int64
#  32  skill_fk_accuracy           17547 non-null  int64
#  33  skill_long_passing          17547 non-null  int64
#  34  skill_ball_control          17547 non-null  int64
#  35  movement_acceleration       17547 non-null  int64
#  36  movement_sprint_speed       17547 non-null  int64
#  37  movement_agility            17547 non-null  int64
#  38  movement_reactions          17547 non-null  int64
#  39  movement_balance            17547 non-null  int64
#  40  power_shot_power            17547 non-null  int64
#  41  power_jumping               17547 non-null  int64
#  42  power_stamina               17547 non-null  int64
#  43  power_strength              17547 non-null  int64
#  44  power_long_shots            17547 non-null  int64
#  45  mentality_aggression        17547 non-null  int64
#  46  mentality_interceptions     17547 non-null  int64
#  47  mentality_positioning       17547 non-null  int64
#  48  mentality_vision            17547 non-null  int64
#  49  mentality_penalties         17547 non-null  int64
#  50  mentality_composure         17547 non-null  int64
#  51  defending_marking           17547 non-null  int64
#  52  defending_standing_tackle   17547 non-null  int64
#  53  defending_sliding_tackle    17547 non-null  int64
#  54  team_CAM                    17547 non-null  uint8
#  55  team_CB                     17547 non-null  uint8
#  56  team_CDM                    17547 non-null  uint8
#  57  team_CF                     17547 non-null  uint8
#  58  team_CM                     17547 non-null  uint8
#  59  team_GK                     17547 non-null  uint8
#  60  team_LAM                    17547 non-null  uint8
#  61  team_LB                     17547 non-null  uint8
#  62  team_LCB                    17547 non-null  uint8
#  63  team_LCM                    17547 non-null  uint8
#  64  team_LDM                    17547 non-null  uint8
#  65  team_LF                     17547 non-null  uint8
#  66  team_LM                     17547 non-null  uint8
#  67  team_LS                     17547 non-null  uint8
#  68  team_LW                     17547 non-null  uint8
#  69  team_LWB                    17547 non-null  uint8
#  70  team_RAM                    17547 non-null  uint8
#  71  team_RB                     17547 non-null  uint8
#  72  team_RCB                    17547 non-null  uint8
#  73  team_RCM                    17547 non-null  uint8
#  74  team_RDM                    17547 non-null  uint8
#  75  team_RF                     17547 non-null  uint8
#  76  team_RM                     17547 non-null  uint8
#  77  team_RS                     17547 non-null  uint8
#  78  team_RW                     17547 non-null  uint8
#  79  team_RWB                    17547 non-null  uint8
#  80  team_ST                     17547 non-null  uint8
#  81  work_rate_att_High          17547 non-null  uint8
#  82  work_rate_att_Low           17547 non-null  uint8
#  83  work_rate_att_Medium        17547 non-null  uint8
#  84  work_rate_def_High          17547 non-null  uint8
#  85  work_rate_def_Low           17547 non-null  uint8
#  86  work_rate_def_Medium        17547 non-null  uint8
# dtypes: float64(13), int64(40), object(1), uint8(33)
# memory usage: 7.9+ MB

# %% [markdown]
# **Observation in this section**
#
# Varius techniques are used to drop rows, drop columns, to replace missing values in each column, and to trannsform all the data into a similar fashion. Each column has different properties and appropriate techniques are applied on the data to gain as much information as possible for the model to learn. After this step, dataset has 17547 rows and 87 columns with out null values.

# %% [markdown]
# ## **Hypothesis Testing to remove insignificant columns**

# %%
# Get all the columns except 'overall' as the predictors
X = df.drop(['overall'],axis=1)

# Select 'overall' as the response variable
y = df['overall']

# %%
# Initialize a linear regression model with normalize=True
lreg = LinearRegression(normalize=True)

# Fit the model on the entire data
lreg.fit(X, y)
# Out:
# LinearRegression(normalize=True)

# %%
#storing the values in two lists
coef_dict = dict(zip(df.columns[:-1], np.transpose(lreg.coef_)))
predictors,coefficients = list(zip(*sorted(coef_dict.items(),key=lambda x: x[1])))

# %%
# Helper function to compute the t-statistic 
def get_t(arr):
    means = np.abs(arr.mean(axis=0))
    stds = arr.std(axis=0)
    return np.divide(means,stds)

# %%
# Initialize an empty list to store the coefficient values
coef_dist = []

# Set the number of bootstraps
numboot = 1000

# Loop over the all the bootstraps
for i in range(numboot):

    # Get a bootstrapped version of the dataframe
    df_new = df.sample(frac=1,replace=True)

    # Get all the columns except 'sales' as the predictors
    X = df_new.drop("overall",axis=1)

    # Select 'sales' as the response variable
    y = df_new["overall"]

    # Initialize a linear regression model with normalize=True
    lreg = LinearRegression(normalize=True)

    # Fit the model on the entire data
    lreg.fit(X, y)

    # Append the coefficients of all predictors to the list
    coef_dist.append(lreg.coef_)

# Convert the list to a numpy array
coef_dist = np.array(coef_dist)

# %%
# Use the helper function get_t to find the T-test values
tt = get_t(coef_dist)
n = df.shape[0]

# %%
# Get the t-value associated with each predictor
tt_dict = dict(zip(df.columns[:-1], tt))
predictors, tvalues = list(zip(*sorted(tt_dict.items(),key=lambda x:x[1])))

# %%
# Helper code below to visualise the t-values
fig, ax = plt.subplots(figsize=(15,15))
ax.barh(predictors,tvalues, align='center',color="#336600",alpha=0.7)
ax.grid(linewidth=0.2)
ax.set_xlabel("T-test values")
ax.set_ylabel("Predictors")
fig.suptitle("t-values for predictors")
plt.show();

# %%
#dropping columns which have tvalue less than 5
count=0
to_drop = []
for i in range(len(tvalues)):
    if tvalues[i]<3:
        print(f"{predictors[i]} : {tvalues[i]}")
        to_drop.append(predictors[i])
        count+=1
    
print("total :"+ str(count) + " are being removed")
# Drop features 
df.drop(to_drop, axis=1, inplace=True)
# Out:
# team_CDM : 0.0024359851182808117
# team_CF : 0.002435985118347053
# team_RCB : 0.0024359851184016868
# team_LCB : 0.0024359851184506823
# team_LAM : 0.0024359851184668916
# team_LW : 0.002435985118473176
# team_LCM : 0.002435985118513782
# team_RAM : 0.002435985118526341
# team_RCM : 0.0024359851185304826
# team_CB : 0.00243598511853356
# team_CM : 0.002435985118567162
# team_RW : 0.00243598511859343
# team_RM : 0.002435985118600488
# team_LM : 0.0024359851186170397
# team_LDM : 0.002435985118646551
# team_RWB : 0.002435985118652841
# team_LS : 0.002435985118710188
# team_RS : 0.002435985118717704
# team_RF : 0.0024359851187416193
# team_RDM : 0.002435985118751804
# defending_sliding_tackle : 0.0024359851187723716
# team_LF : 0.0024359851187777232
# team_GK : 0.0024359851188686245
# team_CAM : 0.002435985119004935
# team_LB : 0.002435985119009578
# team_LWB : 0.002435985119021677
# team_RB : 0.002435985119077493
# work_rate_att_Medium : 0.022824902850135317
# work_rate_def_Low : 0.022824902850154115
# work_rate_def_High : 0.022824902850274685
# work_rate_att_High : 0.023687520296183755
# work_rate_att_Low : 0.023687520296527147
# team_ST : 0.023687520296533846
# release_clause_eur : 0.05391156349892768
# nation_position : 0.4850959090882667
# preferred_foot : 0.9682032436846174
# value_eur : 0.9873693001634418
# skill_dribbling : 1.037955948909739
# international_reputation : 1.188052781546466
# attacking_crossing : 1.3568842253359736
# gk_handling : 1.6967564314687953
# power_shot_power : 1.7056692864751866
# gk_reflexes : 1.7573925809407926
# movement_acceleration : 2.0513761664923584
# height_cm : 2.063106811449839
# pace : 2.1936687405770856
# skill_moves : 2.4599577834663644
# wage_eur : 2.4640146575681747
# movement_balance : 2.8716587869428087
# total :49 are being removed

# %%
df.shape
# Out:
# (17547, 38)

# %% [markdown]
# **Observation in this section**
#
# Columns that proved to be very insignificant i.e., which have less t-value are eliminated in this step. Lesser t-value indicates that the predictors dont produce enough effect on the model. Lot of columns proved to be insignificant and a total of 50 columns are removed in this step. The dataset is now left with 17547 rows in 37 columns.

# %% [markdown]
# ## **Removing columns that are highly correlated**

# %%
#plotting correlation matrix among predictors
corrMatrix = df[df.columns].corr() 
fig, ax = plt.subplots(figsize=(20,20)) 
ax=sns.heatmap(corrMatrix, annot=True) 
fig.suptitle("Correlation matrix for predictors")
plt.show()

# %%
#Dropping features which have correlation value greater than 0.90
corr_matrix = df.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find features with correlation greater than 0.90
to_drop = [column for column in upper.columns if any(upper[column] > 0.90)]

print(len(to_drop))
# Drop features 
df.drop(to_drop, axis=1, inplace=True)
# Out:
# 14

# %%
#printing the final set of columns and their count
print(df.columns,len(df.columns))
# Out:
# Index(['age', 'weight_kg', 'overall', 'weak_foot', 'shooting', 'passing',
#        'defending', 'physic', 'player_traits', 'attacking_heading_accuracy',
#        'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
#        'movement_sprint_speed', 'movement_agility', 'movement_reactions',
#        'power_jumping', 'power_stamina', 'power_strength',
#        'mentality_aggression', 'mentality_vision', 'mentality_penalties',
#        'mentality_composure', 'work_rate_def_Medium'],
#       dtype='object') 24

# %% [markdown]
# **Observations in this section**
#
# when we have highly correlated features, the variance of weights will be large, which in turn indicates that the model is very sensitive to data. It means that the model might not perform well with test data. When we remove high correlated columns(threshold > 90%), the dataset is finally left with 24 columns.

# %% [markdown]
# ## **Implementing Linear Regression**

# %%
# Get all the columns except 'overall' as the predictors
X = df.drop(['overall'],axis=1)

# Select 'overall' as the response variable
y = df['overall']

# Split the data into train and validation sets
# Set the train size to 0.8 and random state to 22
X_train, X_val, y_train, y_val = train_test_split(X,y,train_size=0.8,random_state=22)

# %%
# Helper code to plot x & y to visually inspect the data
fig, ax = plt.subplots()
ax.plot(X,y,'x')
ax.set_xlabel('$x$ values')
ax.set_ylabel('$y$ values')
ax.set_title('$X$ vs $y$')
plt.show()

# %%
# Initialize a linear model
model = LinearRegression()

# Fit the model on the train data
model.fit(X_train,y_train)

# Get the predictions on the validation data using the trained model
y_pred_train = model.predict(X_train)
y_pred_val = model.predict(X_val)

# Compute the MSE for the train and validation data
train_mse = mean_squared_error(y_pred_train, y_train)
val_mse = mean_squared_error(y_pred_val, y_val)

#print the mse
print(f"The training mse is: {train_mse}")
print(f"The validation mse is: {val_mse}")
# Out:
# The training mse is: 8.582051787804287
# The validation mse is: 8.65917472215517

# %%
#computing r2_score 
train_score= r2_score(y_train, y_pred_train)
val_score = r2_score(y_val,y_pred_val)
#print the scores
print(f"The training r2_score is: {train_score:2f}")
print(f"The validation r2_score is: {val_score:2f}")
# Out:
# The training r2_score is: 0.824624
# The validation r2_score is: 0.826789

# %%
fig, ax = plt.subplots(1,1, figsize=(6,6))
ax.scatter(y_train, y_pred_train, s=20, marker='o', c='None', edgecolors='blue', label=f'Train Set R2={train_score.round(4)}')
ax.set_xlabel("Actual Player Rating")
ax.set_ylabel("Predicted Player Rating")
ax.set_title("Predicted Player Rating vs Actual Rating")
ax.plot([50,95], [50,95], c='k', label="1:1 line")
fig.suptitle("Actual vs Predicted rating of players in train data")
ax.legend()

# %%
fig, ax = plt.subplots(1,1, figsize=(6,6))
ax.scatter(y_val, y_pred_val, s=20, marker='o', c='None', edgecolors='red', label=f'Validation Set R2={val_score.round(4)}')
ax.set_xlabel("Actual Player Rating")
ax.set_ylabel("Predicted Player Rating")
ax.set_title("Predicted Player Rating vs Actual Rating")
ax.plot([50,95], [50,95], c='k', label="1:1 line")
fig.suptitle("Actual vs Predicted rating of players in validtion data")
ax.legend()

# %% [markdown]
# **Observations in this section**
#
# Linear Regression model has performed well in this data.
# The training and validation mse is around 8 and r2_scores are around 82

# %% [markdown]
# ## **Preprocessing players_20 dataset using same techniques as players_19 dataset**

# %%
#reading the 2020 players dataset
df1=pd.read_csv("https://raw.githubusercontent.com/rraj29/data/main/players_20.csv")
df1.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# 0        170         72   Argentina         FC Barcelona  ...  68+2  66+2
# 1        187         83    Portugal             Juventus  ...  65+3  61+3
# 2        175         68      Brazil  Paris Saint-Germain  ...  66+3  61+3
# 3        188         87    Slovenia      Atlético Madrid  ...   NaN   NaN
# 4        175         74     Belgium          Real Madrid  ...  66+3  63+3
#
#     cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0  66+2  66+2  68+2  63+2  52+2  52+2  52+2  63+2
# 1  61+3  61+3  65+3  61+3  53+3  53+3  53+3  61+3
# 2  61+3  61+3  66+3  61+3  46+3  46+3  46+3  61+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  63+3  63+3  66+3  61+3  49+3  49+3  49+3  61+3
#
# [5 rows x 104 columns]

# %%
df1.shape
# Out:
# (18278, 104)

# %%
na = pd.notnull(df1["team_position"])
df1 = df1[na]

# %%
df1.shape
# Out:
# (18038, 104)

# %%
#Remove the last 31 columns 
df1 = df1.iloc[: , :-31]

# Remove the columns suggested in the project description
df1.drop(["sofifa_id", "player_url", "short_name","long_name", "real_face", "potential"],axis=1,inplace=True)

# Remove the columns that should not make a difference
df1.drop(["dob", "nationality", "player_positions", "body_type", "loaned_from", "joined", "contract_valid_until"],axis=1,inplace=True)

# Removing the columns for team_jersey_number and nation_jersey_number. These should not make a difference
df1.drop(["player_tags", "team_jersey_number", "nation_jersey_number"],axis=1,inplace=True)

na = pd.notnull(df1["team_position"])
df1 = df1[na]

for i in df1.columns[14:26]:
    print("filling missing values in :"+i)
    df1[i]=df1[i].fillna(0)

df1["release_clause_eur"].fillna(0.0, inplace=True)

for i in df1.columns[28:]:
    print("evaluating values in column :"+i)
    df1[i]=df1[i].apply(lambda x: eval(x) if isinstance(x,str) else x)

df1["preferred_foot"] = df1["preferred_foot"].map({"Left":0, 'Right':1})

df1["nation_position"]= df1["nation_position"].apply(lambda x:0 if x == np.nan else 1)

df1["team_position"].replace('RES', 'GK', inplace=True)
df1["team_position"].replace('SUB', 'GK', inplace=True)
df1_encoded_team=pd.get_dummies(df1["team_position"],prefix="team",drop_first=False)
df1=pd.concat([df1,df1_encoded_team],axis=1)
df1.drop(["team_position"],axis=1,inplace=True)

df1["work_rate_att"]=df1["work_rate"].apply(lambda x: x.split("/")[0])
df1["work_rate_def"]=df1["work_rate"].apply(lambda x: x.split("/")[1])
df1_att=pd.get_dummies(df1["work_rate_att"],prefix="work_rate_att",drop_first=False)
df1_def=pd.get_dummies(df1["work_rate_def"],prefix="work_rate_def",drop_first=False)
df1=pd.concat([df1,df1_att,df1_def],axis=1)
df1.drop(["work_rate", "work_rate_att", "work_rate_def"],axis=1,inplace=True)

df1["player_traits"].fillna('', inplace=True)
for i in range(df1.shape[0]):
    a=df1["player_traits"].iloc[i]
    b=len(a.split(','))
    if a=='':
        b=0
    df1["player_traits"].iloc[i]=b
# Out:
# filling missing values in :nation_position
# filling missing values in :pace
# filling missing values in :shooting
# filling missing values in :passing
# filling missing values in :dribbling
# filling missing values in :defending
# filling missing values in :physic
# filling missing values in :gk_diving
# filling missing values in :gk_handling
# filling missing values in :gk_kicking
# filling missing values in :gk_reflexes
# filling missing values in :gk_speed
# evaluating values in column :attacking_crossing
# evaluating values in column :attacking_finishing
# evaluating values in column :attacking_heading_accuracy
# evaluating values in column :attacking_short_passing
# evaluating values in column :attacking_volleys
# evaluating values in column :skill_dribbling
# evaluating values in column :skill_curve
# evaluating values in column :skill_fk_accuracy
# evaluating values in column :skill_long_passing
# evaluating values in column :skill_ball_control
# evaluating values in column :movement_acceleration
# evaluating values in column :movement_sprint_speed
# evaluating values in column :movement_agility
# evaluating values in column :movement_reactions
# evaluating values in column :movement_balance
# evaluating values in column :power_shot_power
# evaluating values in column :power_jumping
# evaluating values in column :power_stamina
# evaluating values in column :power_strength
# evaluating values in column :power_long_shots
# evaluating values in column :mentality_aggression
# evaluating values in column :mentality_interceptions
# evaluating values in column :mentality_positioning
# evaluating values in column :mentality_vision
# evaluating values in column :mentality_penalties
# evaluating values in column :mentality_composure
# evaluating values in column :defending_marking
# evaluating values in column :defending_standing_tackle
# evaluating values in column :defending_sliding_tackle

# %%
df1.info(verbose=True,show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18038 entries, 0 to 18277
# Data columns (total 88 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         18038 non-null  int64
#  1   height_cm                   18038 non-null  int64
#  2   weight_kg                   18038 non-null  int64
#  3   club                        18038 non-null  object
#  4   overall                     18038 non-null  int64
#  5   value_eur                   18038 non-null  int64
#  6   wage_eur                    18038 non-null  int64
#  7   preferred_foot              18038 non-null  int64
#  8   international_reputation    18038 non-null  int64
#  9   weak_foot                   18038 non-null  int64
#  10  skill_moves                 18038 non-null  int64
#  11  release_clause_eur          18038 non-null  float64
#  12  nation_position             18038 non-null  int64
#  13  pace                        18038 non-null  float64
#  14  shooting                    18038 non-null  float64
#  15  passing                     18038 non-null  float64
#  16  dribbling                   18038 non-null  float64
#  17  defending                   18038 non-null  float64
#  18  physic                      18038 non-null  float64
#  19  gk_diving                   18038 non-null  float64
#  20  gk_handling                 18038 non-null  float64
#  21  gk_kicking                  18038 non-null  float64
#  22  gk_reflexes                 18038 non-null  float64
#  23  gk_speed                    18038 non-null  float64
#  24  gk_positioning              1996 non-null   float64
#  25  player_traits               18038 non-null  object
#  26  attacking_crossing          18038 non-null  int64
#  27  attacking_finishing         18038 non-null  int64
#  28  attacking_heading_accuracy  18038 non-null  int64
#  29  attacking_short_passing     18038 non-null  int64
#  30  attacking_volleys           18038 non-null  int64
#  31  skill_dribbling             18038 non-null  int64
#  32  skill_curve                 18038 non-null  int64
#  33  skill_fk_accuracy           18038 non-null  int64
#  34  skill_long_passing          18038 non-null  int64
#  35  skill_ball_control          18038 non-null  int64
#  36  movement_acceleration       18038 non-null  int64
#  37  movement_sprint_speed       18038 non-null  int64
#  38  movement_agility            18038 non-null  int64
#  39  movement_reactions          18038 non-null  int64
#  40  movement_balance            18038 non-null  int64
#  41  power_shot_power            18038 non-null  int64
#  42  power_jumping               18038 non-null  int64
#  43  power_stamina               18038 non-null  int64
#  44  power_strength              18038 non-null  int64
#  45  power_long_shots            18038 non-null  int64
#  46  mentality_aggression        18038 non-null  int64
#  47  mentality_interceptions     18038 non-null  int64
#  48  mentality_positioning       18038 non-null  int64
#  49  mentality_vision            18038 non-null  int64
#  50  mentality_penalties         18038 non-null  int64
#  51  mentality_composure         18038 non-null  int64
#  52  defending_marking           18038 non-null  int64
#  53  defending_standing_tackle   18038 non-null  int64
#  54  defending_sliding_tackle    18038 non-null  int64
#  55  team_CAM                    18038 non-null  uint8
#  56  team_CB                     18038 non-null  uint8
#  57  team_CDM                    18038 non-null  uint8
#  58  team_CF                     18038 non-null  uint8
#  59  team_CM                     18038 non-null  uint8
#  60  team_GK                     18038 non-null  uint8
#  61  team_LAM                    18038 non-null  uint8
#  62  team_LB                     18038 non-null  uint8
#  63  team_LCB                    18038 non-null  uint8
#  64  team_LCM                    18038 non-null  uint8
#  65  team_LDM                    18038 non-null  uint8
#  66  team_LF                     18038 non-null  uint8
#  67  team_LM                     18038 non-null  uint8
#  68  team_LS                     18038 non-null  uint8
#  69  team_LW                     18038 non-null  uint8
#  70  team_LWB                    18038 non-null  uint8
#  71  team_RAM                    18038 non-null  uint8
#  72  team_RB                     18038 non-null  uint8
#  73  team_RCB                    18038 non-null  uint8
#  74  team_RCM                    18038 non-null  uint8
#  75  team_RDM                    18038 non-null  uint8
#  76  team_RF                     18038 non-null  uint8
#  77  team_RM                     18038 non-null  uint8
#  78  team_RS                     18038 non-null  uint8
#  79  team_RW                     18038 non-null  uint8
#  80  team_RWB                    18038 non-null  uint8
#  81  team_ST                     18038 non-null  uint8
#  82  work_rate_att_High          18038 non-null  uint8
#  83  work_rate_att_Low           18038 non-null  uint8
#  84  work_rate_att_Medium        18038 non-null  uint8
#  85  work_rate_def_High          18038 non-null  uint8
#  86  work_rate_def_Low           18038 non-null  uint8
#  87  work_rate_def_Medium        18038 non-null  uint8
# dtypes: float64(13), int64(40), object(2), uint8(33)
# memory usage: 8.3+ MB

# %%
df1.shape
# Out:
# (18038, 88)

# %%
for i in df1.columns[:-1]:
        if i != "club":
                print('converting '+i)
                df1[i] = df1[i].apply(pd.to_numeric)
# Out:
# converting age
# converting height_cm
# converting weight_kg
# converting overall
# converting value_eur
# converting wage_eur
# converting preferred_foot
# converting international_reputation
# converting weak_foot
# converting skill_moves
# converting release_clause_eur
# converting nation_position
# converting pace
# converting shooting
# converting passing
# converting dribbling
# converting defending
# converting physic
# converting gk_diving
# converting gk_handling
# converting gk_kicking
# converting gk_reflexes
# converting gk_speed
# converting gk_positioning
# converting player_traits
# converting attacking_crossing
# converting attacking_finishing
# converting attacking_heading_accuracy
# converting attacking_short_passing
# converting attacking_volleys
# converting skill_dribbling
# converting skill_curve
# converting skill_fk_accuracy
# converting skill_long_passing
# converting skill_ball_control
# converting movement_acceleration
# converting movement_sprint_speed
# converting movement_agility
# converting movement_reactions
# converting movement_balance
# converting power_shot_power
# converting power_jumping
# converting power_stamina
# converting power_strength
# converting power_long_shots
# converting mentality_aggression
# converting mentality_interceptions
# converting mentality_positioning
# converting mentality_vision
# converting mentality_penalties
# converting mentality_composure
# converting defending_marking
# converting defending_standing_tackle
# converting defending_sliding_tackle
# converting team_CAM
# converting team_CB
# converting team_CDM
# converting team_CF
# converting team_CM
# converting team_GK
# converting team_LAM
# converting team_LB
# converting team_LCB
# converting team_LCM
# converting team_LDM
# converting team_LF
# converting team_LM
# converting team_LS
# converting team_LW
# converting team_LWB
# converting team_RAM
# converting team_RB
# converting team_RCB
# converting team_RCM
# converting team_RDM
# converting team_RF
# converting team_RM
# converting team_RS
# converting team_RW
# converting team_RWB
# converting team_ST
# converting work_rate_att_High
# converting work_rate_att_Low
# converting work_rate_att_Medium
# converting work_rate_def_High
# converting work_rate_def_Low

# %%
#removing columns that are dropped from 2019 dataset
col20_list=list(df.columns)
#Appending club column as it is needed to filter the test data
col20_list.append("club")
#col20_list

# %%
df1.shape
# Out:
# (18038, 88)

# %%
df1=df1[col20_list]
df1.shape
# Out:
# (18038, 25)

# %%
df1.info(verbose=True,show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18038 entries, 0 to 18277
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         18038 non-null  int64
#  1   weight_kg                   18038 non-null  int64
#  2   overall                     18038 non-null  int64
#  3   weak_foot                   18038 non-null  int64
#  4   shooting                    18038 non-null  float64
#  5   passing                     18038 non-null  float64
#  6   defending                   18038 non-null  float64
#  7   physic                      18038 non-null  float64
#  8   player_traits               18038 non-null  int64
#  9   attacking_heading_accuracy  18038 non-null  int64
#  10  skill_curve                 18038 non-null  int64
#  11  skill_fk_accuracy           18038 non-null  int64
#  12  skill_long_passing          18038 non-null  int64
#  13  movement_sprint_speed       18038 non-null  int64
#  14  movement_agility            18038 non-null  int64
#  15  movement_reactions          18038 non-null  int64
#  16  power_jumping               18038 non-null  int64
#  17  power_stamina               18038 non-null  int64
#  18  power_strength              18038 non-null  int64
#  19  mentality_aggression        18038 non-null  int64
#  20  mentality_vision            18038 non-null  int64
#  21  mentality_penalties         18038 non-null  int64
#  22  mentality_composure         18038 non-null  int64
#  23  work_rate_def_Medium        18038 non-null  uint8
#  24  club                        18038 non-null  object
# dtypes: float64(4), int64(19), object(1), uint8(1)
# memory usage: 3.5+ MB

# %% [markdown]
# **Observations in this section**
#
# Deleting all the columns that are dropped from players_19 dataset after implementing similar preprocessing techniques. clubs column is not dropped here as that is needed later to filter rows in making test dataset. Dataset is finally left with around 20 columns (including club column)

# %% [markdown]
# ## **Preparing the test dataset**

# %%
#filtering rows belonging to required clubs
club_list=["FC Barcelona","FC Bayern München","Real Madrid","Paris Saint-Germain","Juventus","Manchester City","Liverpool FC"]
df1_test=df1[df1["club"].isin(club_list)]
df1_test.head()
# Out:
#    age  weight_kg  overall  weak_foot  shooting  passing  defending  physic  \
# 0   32         72       94          4      92.0     92.0       39.0    66.0
# 1   34         83       93          4      93.0     82.0       35.0    78.0
# 2   27         68       92          5      85.0     87.0       32.0    58.0
# 4   28         74       91          4      83.0     86.0       35.0    66.0
# 5   28         70       91          5      86.0     92.0       61.0    78.0
#
#    player_traits  attacking_heading_accuracy  ...  movement_reactions  \
# 0              8                          70  ...                  95
# 1              6                          89  ...                  96
# 2              6                          62  ...                  92
# 4              5                          61  ...                  90
# 5              6                          55  ...                  91
#
#    power_jumping  power_stamina  power_strength  mentality_aggression  \
# 0             68             75              68                    48
# 1             95             85              78                    63
# 2             61             81              49                    51
# 4             56             84              63                    54
# 5             63             89              74                    76
#
#    mentality_vision  mentality_penalties  mentality_composure  \
# 0                94                   75                   96
# 1                82                   85                   95
# 2                90                   90                   94
# 4                89                   88                   91
# 5                94                   79                   91
#
#    work_rate_def_Medium                 club
# 0                     0         FC Barcelona
# 1                     0             Juventus
# 2                     1  Paris Saint-Germain
# 4                     1          Real Madrid
# 5                     0      Manchester City
#
# [5 rows x 25 columns]

# %%
df1_test.shape
# Out:
# (188, 25)

# %% [markdown]
# **Observations in this section**
#
# After filtering out the rows, test data is left with 188 rows and 19 columns, among which clubs will be removed in the next step.

# %% [markdown]
# ## **Predicting and computing the results**

# %%
#Splitting the test data to X and y
X_20=df1_test.drop(["overall","club"],axis=1)
y_20=df1_test["overall"]

# %%
#Predicting on the test data using the model
y_20_pred=model.predict(X_20)

# %%
#computing the mse
test_mse = mean_squared_error(y_20_pred, y_20)
print(f"The prediction mse is: {test_mse}")
# Out:
# The prediction mse is: 10.348733173961666

# %%
#computing the r2_score on test data
test_score= r2_score(y_20, y_20_pred)
#print the scores
print(f"The r2_score for test data is: {test_score:2f}")
# Out:
# The r2_score for test data is: 0.873994

# %%
fig, ax = plt.subplots(1,1, figsize=(6,6))
ax.scatter(y_20, y_20_pred, s=20, marker='o', c='None', edgecolors='red', label=f'Test Set R2={test_score.round(4)}')
ax.set_xlabel("Actual Player Rating")
ax.set_ylabel("Predicted Player Rating")
ax.plot([50,95], [50,95], c='k', label="1:1 line")
fig.suptitle("Actual vs Predicted rating of players in test data")
ax.legend()

# %% [markdown]
# **Observations in this section**
#
# The mse for test set is around 10 and r2_score was around 0.87

# %% [markdown]
# ## **The best player**

# %%
#checking the predcited values
max_overall_value=max(y_20_pred)
best_player_index=np.where(y_20_pred == max_overall_value)
print(f'The best player has an overall score of {max(y_20_pred)} at an index of {best_player_index[0][0]}')
# Out:
# The best player has an overall score of 93.1541966837066 at an index of 1

# %%
#checking the details of the top ranked players
best_player_row=X_20[:][best_player_index[0][0]:best_player_index[0][0]+1]

# %%
best_player_row
# Out:
#    age  weight_kg  weak_foot  shooting  passing  defending  physic  \
# 1   34         83          4      93.0     82.0       35.0    78.0
#
#    player_traits  attacking_heading_accuracy  skill_curve  ...  \
# 1              6                          89           81  ...
#
#    movement_agility  movement_reactions  power_jumping  power_stamina  \
# 1                87                  96             95             85
#
#    power_strength  mentality_aggression  mentality_vision  \
# 1              78                    63                82
#
#    mentality_penalties  mentality_composure  work_rate_def_Medium
# 1                   85                   95                     0
#
# [1 rows x 23 columns]

# %%
best_player_age=best_player_row["age"]
best_player_weight=best_player_row["weight_kg"]
best_player_passing=best_player_row["passing"]

# %%
#finding out the best player
df_ans=pd.read_csv("https://raw.githubusercontent.com/rraj29/data/main/players_20.csv")
best_player=df_ans[(df_ans["age"]==best_player_age[1])&(df_ans["weight_kg"]==best_player_weight[1])&(df_ans["passing"]==best_player_passing[1])]

# %%
best_player
# Out:
#    sofifa_id                                         player_url  \
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
#
#           short_name                            long_name  age         dob  \
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
#
#    height_cm  weight_kg nationality      club  ...   lwb   ldm   cdm   rdm  \
# 1        187         83    Portugal  Juventus  ...  65+3  61+3  61+3  61+3
#
#     rwb    lb   lcb    cb   rcb    rb
# 1  65+3  61+3  53+3  53+3  53+3  61+3
#
# [1 rows x 104 columns]

# %%
print("The best player is "+ best_player["short_name"])
# Out:
# 1    The best player is Cristiano Ronaldo
# Name: short_name, dtype: object

# %% [markdown]
# **Observations in this section**
#
# * The best player is Ronaldo with an overall score of around 93

# %% [markdown]
# Please note that all the results mentioned in the text fields are having a buffer of +2 to +2. It keeps varying a little everytime we run the cells.
